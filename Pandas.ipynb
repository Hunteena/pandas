# %% [markdown]
# # <center> Тестовое задание для вакансии “Backend разработчик (Python, Junior)”

# %% [markdown]
# ## <center> Загружаем данные

# %%
import json
import pandas as pd

# %%
file_path = 'trial_task.json'

with open(file_path, 'r') as json_file:
    data = json.load(json_file)


product_records = []

for order in data:
    order_id = order['order_id']
    warehouse_name = order['warehouse_name']
    highway_cost = order['highway_cost']
    for product_data in order['products']:
        product = product_data['product']
        price = product_data['price']
        quantity = product_data['quantity']

        product_record = {
            'order_id': order_id,
            'warehouse_name': warehouse_name,
            'highway_cost': highway_cost,
            'product': product,
            'price': price,
            'quantity': quantity
        }

        product_records.append(product_record)

df = pd.DataFrame(product_records)

df
# Out:
#      order_id       warehouse_name  highway_cost                   product  \
# 0       11973               Мордор           -70     ломтик июльского неба
# 1       11973               Мордор           -70           билет в Израиль
# 2       11973               Мордор           -70          статуэтка Ленина
# 3       62239  хутор близ Диканьки           -15           билет в Израиль
# 4       85794           отель Лето           -50         зеленая пластинка
# ..        ...                  ...           ...                       ...
# 192     79293           отель Лето           -75  автограф Стаса Барецкого
# 193     79293           отель Лето           -75     ломтик июльского неба
# 194      2930               Мордор           -30                   плюмбус
# 195      2930               Мордор           -30                   плюмбус
# 196       124  хутор близ Диканьки           -45                   плюмбус
#
#      price  quantity
# 0      450         1
# 1     1000         3
# 2      200         3
# 3     1000         1
# 4       10         2
# ..     ...       ...
# 192    600         1
# 193    450         1
# 194    250         2
# 195    250         1
# 196    250         3
#
# [197 rows x 6 columns]

# %% [markdown]
# ## <center> Задачи

# %% [markdown]
# ### 1. Найти тариф стоимости доставки для каждого склада

# %% [markdown]
# Сначала находим общее количество единиц товара для каждого заказа:

# %%
qty_per_order = df.groupby('order_id')['quantity'].sum().reset_index()
qty_per_order.rename(columns={'quantity': 'order_total_qty'}, inplace=True)

qty_per_order
# Out:
#     order_id  order_total_qty
# 0        124                3
# 1       1391                2
# 2       2091                4
# 3       2108                2
# 4       2558                5
# ..       ...              ...
# 95     98100                2
# 96     98423                2
# 97     99220                5
# 98     99246                3
# 99     99324                2
#
# [100 rows x 2 columns]

# %% [markdown]
# Теперь присоединяем эти количества к основной таблице и рассчитываем тариф для каждого товара:

# %%
df = df.merge(qty_per_order, on='order_id')

df['tariff'] = df['highway_cost'] // df['order_total_qty']

df
# Out:
#      order_id       warehouse_name  highway_cost                   product  \
# 0       11973               Мордор           -70     ломтик июльского неба
# 1       11973               Мордор           -70           билет в Израиль
# 2       11973               Мордор           -70          статуэтка Ленина
# 3       62239  хутор близ Диканьки           -15           билет в Израиль
# 4       85794           отель Лето           -50         зеленая пластинка
# ..        ...                  ...           ...                       ...
# 192     79293           отель Лето           -75  автограф Стаса Барецкого
# 193     79293           отель Лето           -75     ломтик июльского неба
# 194      2930               Мордор           -30                   плюмбус
# 195      2930               Мордор           -30                   плюмбус
# 196       124  хутор близ Диканьки           -45                   плюмбус
#
#      price  quantity  order_total_qty  tariff
# 0      450         1                7     -10
# 1     1000         3                7     -10
# 2      200         3                7     -10
# 3     1000         1                1     -15
# 4       10         2                2     -25
# ..     ...       ...              ...     ...
# 192    600         1                3     -25
# 193    450         1                3     -25
# 194    250         2                3     -10
# 195    250         1                3     -10
# 196    250         3                3     -15
#
# [197 rows x 8 columns]

# %% [markdown]
# Теперь мы можем вывести тарифы для каждого склада:

# %%
df.groupby('warehouse_name')['tariff'].first().reset_index()
# Out:
#         warehouse_name  tariff
# 0               Мордор     -10
# 1           гиперборея     -20
# 2     остров невезения      -5
# 3           отель Лето     -25
# 4  хутор близ Диканьки     -15

# %% [markdown]
# ### 2. Найти суммарное количество , суммарный доход , суммарный расход и суммарную прибыль для каждого товара (представить как таблицу со столбцами 'product', 'quantity', 'income', 'expenses', 'profit')

# %% [markdown]
# Добавляем в основную таблицу стоблцы с доходом, расходом и прибылью:

# %%
df['income'] = df['price'] * df['quantity']
df['expenses'] = df['tariff'] * df['quantity']
df['profit'] = df['income'] + df['expenses']

df.head()
# Out:
#    order_id       warehouse_name  highway_cost                product  price  \
# 0     11973               Мордор           -70  ломтик июльского неба    450
# 1     11973               Мордор           -70        билет в Израиль   1000
# 2     11973               Мордор           -70       статуэтка Ленина    200
# 3     62239  хутор близ Диканьки           -15        билет в Израиль   1000
# 4     85794           отель Лето           -50      зеленая пластинка     10
#
#    quantity  order_total_qty  tariff  income  expenses  profit
# 0         1                7     -10     450       -10     440
# 1         3                7     -10    3000       -30    2970
# 2         3                7     -10     600       -30     570
# 3         1                1     -15    1000       -15     985
# 4         2                2     -25      20       -50     -30

# %% [markdown]
# Группируем по продукту:

# %%
products = df.groupby('product')[['quantity', 'income', 'expenses', 'profit']].sum().reset_index()
products
# Out:
#                     product  quantity  income  expenses  profit
# 0  автограф Стаса Барецкого        48   28800      -820   27980
# 1           билет в Израиль        58   58000     -1050   56950
# 2         зеленая пластинка        61     610      -920    -310
# 3     ломтик июльского неба        42   18900      -670   18230
# 4                   плюмбус        65   16250      -940   15310
# 5    подписка на suppi-блог        33    4950      -545    4405
# 6          статуэтка Ленина        68   13600      -935   12665

# %% [markdown]
# ### 3. Составить табличку со столбцами 'order_id' (id заказа) и 'order_profit' (прибыль полученная с заказа). А также вывести среднюю прибыль заказов

# %% [markdown]
# Находим суммарную прибыль каждого заказа:

# %%
profit_per_order = df.groupby('order_id')['profit'].sum().reset_index()
profit_per_order.rename(columns={'profit': 'order_profit'}, inplace=True)
profit_per_order
# Out:
#     order_id  order_profit
# 0        124           705
# 1       1391           490
# 2       2091          1300
# 3       2108           200
# 4       2558           355
# ..       ...           ...
# 95     98100          1590
# 96     98423          1170
# 97     99220          1075
# 98     99246          1755
# 99     99324          1590
#
# [100 rows x 2 columns]

# %% [markdown]
# Находим среднюю прибыль заказов:

# %%
profit_per_order['order_profit'].mean()
# Out:
# 1352.3

# %% [markdown]
# ### 4. Составить табличку типа 'warehouse_name' , 'product','quantity', 'profit', 'percent_profit_product_of_warehouse' (процент прибыли продукта заказанного из определенного склада к прибыли этого склада)

# %% [markdown]
# Находим суммарную прибыль по каждому заказу:

# %%
warehouse_profit = df.groupby(['warehouse_name'])['profit'].sum().reset_index()
warehouse_profit.rename(columns={'profit': 'warehouse_profit'}, inplace=True) 

warehouse_profit
# Out:
#         warehouse_name  warehouse_profit
# 0               Мордор             17050
# 1           гиперборея             38280
# 2     остров невезения             15610
# 3           отель Лето             27050
# 4  хутор близ Диканьки             37240

# %% [markdown]
# Группируем основную таблицу по складу и продукту. Для расчёта процента прибыли продукта добавляем столбец с суммарной прибылью по каждому складу, а после расчёта - удаляем этот столбец.

# %%
product_profit_percent = df.groupby(
    ['warehouse_name', 'product']
)[['quantity', 'profit']].sum().reset_index().merge(
    warehouse_profit, on='warehouse_name'
)

product_profit_percent['percent_profit_product_of_warehouse'] = (
    product_profit_percent['profit'] / product_profit_percent['warehouse_profit'] * 100
)
product_profit_percent.drop(columns='warehouse_profit', inplace=True)

product_profit_percent
# Out:
#          warehouse_name                   product  quantity  profit  \
# 0                Мордор  автограф Стаса Барецкого         4    2360
# 1                Мордор           билет в Израиль         9    8910
# 2                Мордор         зеленая пластинка        11       0
# 3                Мордор     ломтик июльского неба         3    1320
# 4                Мордор                   плюмбус         6    1440
# 5                Мордор    подписка на suppi-блог         8    1120
# 6                Мордор          статуэтка Ленина        10    1900
# 7            гиперборея  автограф Стаса Барецкого        12    6960
# 8            гиперборея           билет в Израиль        21   20580
# 9            гиперборея         зеленая пластинка        10    -100
# 10           гиперборея     ломтик июльского неба        13    5590
# 11           гиперборея                   плюмбус         9    2070
# 12           гиперборея    подписка на suppi-блог        12    1560
# 13           гиперборея          статуэтка Ленина         9    1620
# 14     остров невезения  автограф Стаса Барецкого         2    1190
# 15     остров невезения           билет в Израиль         3    2985
# 16     остров невезения         зеленая пластинка         9      45
# 17     остров невезения     ломтик июльского неба        10    4450
# 18     остров невезения                   плюмбус        14    3430
# 19     остров невезения          статуэтка Ленина        18    3510
# 20           отель Лето  автограф Стаса Барецкого         8    4600
# 21           отель Лето           билет в Израиль        15   14625
# 22           отель Лето         зеленая пластинка        10    -150
# 23           отель Лето     ломтик июльского неба         9    3825
# 24           отель Лето                   плюмбус         9    2025
# 25           отель Лето    подписка на suppi-блог         3     375
# 26           отель Лето          статуэтка Ленина        10    1750
# 27  хутор близ Диканьки  автограф Стаса Барецкого        22   12870
# 28  хутор близ Диканьки           билет в Израиль        10    9850
# 29  хутор близ Диканьки         зеленая пластинка        21    -105
# 30  хутор близ Диканьки     ломтик июльского неба         7    3045
# 31  хутор близ Диканьки                   плюмбус        27    6345
# 32  хутор близ Диканьки    подписка на suppi-блог        10    1350
# 33  хутор близ Диканьки          статуэтка Ленина        21    3885
#
#     percent_profit_product_of_warehouse
# 0                             13.841642
# 1                             52.258065
# 2                              0.000000
# 3                              7.741935
# 4                              8.445748
# 5                              6.568915
# 6                             11.143695
# 7                             18.181818
# 8                             53.761755
# 9                             -0.261233
# 10                            14.602926
# 11                             5.407524
# 12                             4.075235
# 13                             4.231975
# 14                             7.623318
# 15                            19.122357
# 16                             0.288277
# 17                            28.507367
# 18                            21.973094
# 19                            22.485586
# 20                            17.005545
# 21                            54.066543
# 22                            -0.554529
# 23                            14.140481
# 24                             7.486137
# 25                             1.386322
# 26                             6.469501
# 27                            34.559613
# 28                            26.450054
# 29                            -0.281955
# 30                             8.176692
# 31                            17.038131
# 32                             3.625134
# 33                            10.432331

# %% [markdown]
# ### 5. Взять предыдущую табличку и отсортировать 'percent_profit_product_of_warehouse' по убыванию, после посчитать накопленный процент. Накопленный процент - это новый столбец в этой табличке, который должен называться 'accumulated_percent_profit_product_of_warehouse'. По своей сути это постоянно растущая сумма отсортированного по убыванию столбца 'percent_profit_product_of_warehouse'.

# %% [markdown]
# Группируем предыдущую таблицу по складу, внутри группы сортируем по убыванию и добавляем накопленный процент:

# %%
product_profit_cum = product_profit_percent.groupby(
    'warehouse_name'
).apply(
    lambda x: x.sort_values('percent_profit_product_of_warehouse', ascending=False)
).reset_index(drop=True)

product_profit_cum['accumulated_percent_profit_product_of_warehouse'] = (
    product_profit_cum.groupby('warehouse_name')['percent_profit_product_of_warehouse'].cumsum()
)

product_profit_cum
# Out:
#          warehouse_name                   product  quantity  profit  \
# 0                Мордор           билет в Израиль         9    8910
# 1                Мордор  автограф Стаса Барецкого         4    2360
# 2                Мордор          статуэтка Ленина        10    1900
# 3                Мордор                   плюмбус         6    1440
# 4                Мордор     ломтик июльского неба         3    1320
# 5                Мордор    подписка на suppi-блог         8    1120
# 6                Мордор         зеленая пластинка        11       0
# 7            гиперборея           билет в Израиль        21   20580
# 8            гиперборея  автограф Стаса Барецкого        12    6960
# 9            гиперборея     ломтик июльского неба        13    5590
# 10           гиперборея                   плюмбус         9    2070
# 11           гиперборея          статуэтка Ленина         9    1620
# 12           гиперборея    подписка на suppi-блог        12    1560
# 13           гиперборея         зеленая пластинка        10    -100
# 14     остров невезения     ломтик июльского неба        10    4450
# 15     остров невезения          статуэтка Ленина        18    3510
# 16     остров невезения                   плюмбус        14    3430
# 17     остров невезения           билет в Израиль         3    2985
# 18     остров невезения  автограф Стаса Барецкого         2    1190
# 19     остров невезения         зеленая пластинка         9      45
# 20           отель Лето           билет в Израиль        15   14625
# 21           отель Лето  автограф Стаса Барецкого         8    4600
# 22           отель Лето     ломтик июльского неба         9    3825
# 23           отель Лето                   плюмбус         9    2025
# 24           отель Лето          статуэтка Ленина        10    1750
# 25           отель Лето    подписка на suppi-блог         3     375
# 26           отель Лето         зеленая пластинка        10    -150
# 27  хутор близ Диканьки  автограф Стаса Барецкого        22   12870
# 28  хутор близ Диканьки           билет в Израиль        10    9850
# 29  хутор близ Диканьки                   плюмбус        27    6345
# 30  хутор близ Диканьки          статуэтка Ленина        21    3885
# 31  хутор близ Диканьки     ломтик июльского неба         7    3045
# 32  хутор близ Диканьки    подписка на suppi-блог        10    1350
# 33  хутор близ Диканьки         зеленая пластинка        21    -105
#
#     percent_profit_product_of_warehouse  \
# 0                             52.258065
# 1                             13.841642
# 2                             11.143695
# 3                              8.445748
# 4                              7.741935
# 5                              6.568915
# 6                              0.000000
# 7                             53.761755
# 8                             18.181818
# 9                             14.602926
# 10                             5.407524
# 11                             4.231975
# 12                             4.075235
# 13                            -0.261233
# 14                            28.507367
# 15                            22.485586
# 16                            21.973094
# 17                            19.122357
# 18                             7.623318
# 19                             0.288277
# 20                            54.066543
# 21                            17.005545
# 22                            14.140481
# 23                             7.486137
# 24                             6.469501
# 25                             1.386322
# 26                            -0.554529
# 27                            34.559613
# 28                            26.450054
# 29                            17.038131
# 30                            10.432331
# 31                             8.176692
# 32                             3.625134
# 33                            -0.281955
#
#     accumulated_percent_profit_product_of_warehouse
# 0                                         52.258065
# 1                                         66.099707
# 2                                         77.243402
# 3                                         85.689150
# 4                                         93.431085
# 5                                        100.000000
# 6                                        100.000000
# 7                                         53.761755
# 8                                         71.943574
# 9                                         86.546499
# 10                                        91.954023
# 11                                        96.185998
# 12                                       100.261233
# 13                                       100.000000
# 14                                        28.507367
# 15                                        50.992953
# 16                                        72.966047
# 17                                        92.088405
# 18                                        99.711723
# 19                                       100.000000
# 20                                        54.066543
# 21                                        71.072089
# 22                                        85.212569
# 23                                        92.698706
# 24                                        99.168207
# 25                                       100.554529
# 26                                       100.000000
# 27                                        34.559613
# 28                                        61.009667
# 29                                        78.047798
# 30                                        88.480129
# 31                                        96.656821
# 32                                       100.281955
# 33                                       100.000000

# %% [markdown]
# ### 6. Присвоить A,B,C - категории на основании значения накопленного процента ('accumulated_percent_profit_product_of_warehouse'). Если значение накопленного процента меньше или равно 70, то категория A. Если от 70 до 90 (включая 90), то категория Б. Остальное - категория C. Новый столбец обозначить в таблице как 'category'

# %% [markdown]
# Для присвоения категории создаём функцию, которую затем используем для создания столбца с категорией:

# %%
def category(cum_percentage):
    if cum_percentage <= 70:
        return 'А'
    elif cum_percentage <= 90:
        return 'Б'
    else:
        return 'С'
    

product_profit_cum['category'] = (
    product_profit_cum['accumulated_percent_profit_product_of_warehouse'].apply(category)
)
product_profit_cum
# Out:
#          warehouse_name                   product  quantity  profit  \
# 0                Мордор           билет в Израиль         9    8910
# 1                Мордор  автограф Стаса Барецкого         4    2360
# 2                Мордор          статуэтка Ленина        10    1900
# 3                Мордор                   плюмбус         6    1440
# 4                Мордор     ломтик июльского неба         3    1320
# 5                Мордор    подписка на suppi-блог         8    1120
# 6                Мордор         зеленая пластинка        11       0
# 7            гиперборея           билет в Израиль        21   20580
# 8            гиперборея  автограф Стаса Барецкого        12    6960
# 9            гиперборея     ломтик июльского неба        13    5590
# 10           гиперборея                   плюмбус         9    2070
# 11           гиперборея          статуэтка Ленина         9    1620
# 12           гиперборея    подписка на suppi-блог        12    1560
# 13           гиперборея         зеленая пластинка        10    -100
# 14     остров невезения     ломтик июльского неба        10    4450
# 15     остров невезения          статуэтка Ленина        18    3510
# 16     остров невезения                   плюмбус        14    3430
# 17     остров невезения           билет в Израиль         3    2985
# 18     остров невезения  автограф Стаса Барецкого         2    1190
# 19     остров невезения         зеленая пластинка         9      45
# 20           отель Лето           билет в Израиль        15   14625
# 21           отель Лето  автограф Стаса Барецкого         8    4600
# 22           отель Лето     ломтик июльского неба         9    3825
# 23           отель Лето                   плюмбус         9    2025
# 24           отель Лето          статуэтка Ленина        10    1750
# 25           отель Лето    подписка на suppi-блог         3     375
# 26           отель Лето         зеленая пластинка        10    -150
# 27  хутор близ Диканьки  автограф Стаса Барецкого        22   12870
# 28  хутор близ Диканьки           билет в Израиль        10    9850
# 29  хутор близ Диканьки                   плюмбус        27    6345
# 30  хутор близ Диканьки          статуэтка Ленина        21    3885
# 31  хутор близ Диканьки     ломтик июльского неба         7    3045
# 32  хутор близ Диканьки    подписка на suppi-блог        10    1350
# 33  хутор близ Диканьки         зеленая пластинка        21    -105
#
#     percent_profit_product_of_warehouse  \
# 0                             52.258065
# 1                             13.841642
# 2                             11.143695
# 3                              8.445748
# 4                              7.741935
# 5                              6.568915
# 6                              0.000000
# 7                             53.761755
# 8                             18.181818
# 9                             14.602926
# 10                             5.407524
# 11                             4.231975
# 12                             4.075235
# 13                            -0.261233
# 14                            28.507367
# 15                            22.485586
# 16                            21.973094
# 17                            19.122357
# 18                             7.623318
# 19                             0.288277
# 20                            54.066543
# 21                            17.005545
# 22                            14.140481
# 23                             7.486137
# 24                             6.469501
# 25                             1.386322
# 26                            -0.554529
# 27                            34.559613
# 28                            26.450054
# 29                            17.038131
# 30                            10.432331
# 31                             8.176692
# 32                             3.625134
# 33                            -0.281955
#
#     accumulated_percent_profit_product_of_warehouse category
# 0                                         52.258065        А
# 1                                         66.099707        А
# 2                                         77.243402        Б
# 3                                         85.689150        Б
# 4                                         93.431085        С
# 5                                        100.000000        С
# 6                                        100.000000        С
# 7                                         53.761755        А
# 8                                         71.943574        Б
# 9                                         86.546499        Б
# 10                                        91.954023        С
# 11                                        96.185998        С
# 12                                       100.261233        С
# 13                                       100.000000        С
# 14                                        28.507367        А
# 15                                        50.992953        А
# 16                                        72.966047        Б
# 17                                        92.088405        С
# 18                                        99.711723        С
# 19                                       100.000000        С
# 20                                        54.066543        А
# 21                                        71.072089        Б
# 22                                        85.212569        Б
# 23                                        92.698706        С
# 24                                        99.168207        С
# 25                                       100.554529        С
# 26                                       100.000000        С
# 27                                        34.559613        А
# 28                                        61.009667        А
# 29                                        78.047798        Б
# 30                                        88.480129        Б
# 31                                        96.656821        С
# 32                                       100.281955        С
# 33                                       100.000000        С
